# %%
import pandas as pd
import numpy as np

# %%
cus_demo = pd.read_csv("CustomerDemographic-Table 1.csv")

# %%
cus_demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
# 2                                   61  1954-01-20      Recruiting Manager
# 3                                   33  1961-10-03                     NaN
# 4                                   56  1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                              1-Feb      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0

# %%
cus_demo=cus_demo.drop(columns=['customer_id','default'])

# %%
cus_demo.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure'],
#       dtype='object')

# %%
cus_demo.isnull().sum()
# Out:
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
cus_demo.shape
# Out:
# (4000, 11)

# %%
cus_demo.deceased_indicator.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
cus_demo.owns_car.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
cus_demo.tenure.unique()
# Out:
# array([11., 16., 15.,  7.,  8., 13., 20.,  9.,  6.,  1., 18., 21., 12.,
#        19., 14.,  4., 22.,  5., 17.,  2.,  3., 10., nan])

# %%
cus_demo['tenure'] = cus_demo['tenure'].fillna(0)

# %%
cus_demo['last_name'] = cus_demo['last_name'].fillna(0)

# %%
cus_demo.dtypes
# Out:
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                 float64
# dtype: object

# %%
cus_demo.sort_values(by=['DOB'], inplace=True)

# %%
cus_demo['DOB'] = cus_demo['DOB'].fillna(0)

# %%
cus_demo.head()
# Out:
#      first_name last_name  gender  past_3_years_bike_related_purchases  \
# 33     Jephthah  Bachmann       U                                   59
# 719      Darrel     Canet    Male                                   67
# 1091     Katlin   Creddon  Female                                   56
# 3409    Merrili   Brittin  Female                                   93
# 2412      Abbey    Murrow    Male                                   27
#
#              DOB                 job_title job_industry_category  \
# 33    1843-12-21           Legal Assistant                    IT
# 719   1931-10-23        Recruiting Manager                Retail
# 1091  1935-08-22        VP Quality Control                Retail
# 3409  1940-09-22                       NaN              Property
# 2412  1943-08-11  Environmental Specialist         Manufacturing
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 719   Affluent Customer                  N       No     6.0
# 1091      Mass Customer                  N       No     5.0
# 3409      Mass Customer                  N       No    16.0
# 2412     High Net Worth                  N      Yes    17.0

# %%
#cus_demo.isnull().sum()

# %%
cus_demo['job_title'] = cus_demo['job_title'].fillna(0)

# %%
cus_demo['job_industry_category'] = cus_demo['job_industry_category'].fillna(0)

# %%
cus_demo.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
#cus_demo.gender.unique()

# %%
cus_demo['gender'] = cus_demo['gender'].replace(['U','F','M'],
                                              ['Undefined','Female','Male'])

# %%
#cus_demo.gender.unique()

# %%
cus_demo['gender'] = cus_demo['gender'].replace(['Femal'],
                                              ['Female'])

# %%
cus_demo.gender.unique()
# Out:
# array(['Undefined', 'Male', 'Female'], dtype=object)

# %%
cus_demo.wealth_segment.unique( )
# Out:
# array(['Affluent Customer', 'Mass Customer', 'High Net Worth'],
#       dtype=object)

# %%
#cus_demo.to_csv('cleaned_cus_demo.csv')

# %%
cus_demo.head(3)
# Out:
#      first_name last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah  Bachmann  Undefined                                   59
# 719      Darrel     Canet       Male                                   67
# 1091     Katlin   Creddon     Female                                   56
#
#              DOB           job_title job_industry_category     wealth_segment  \
# 33    1843-12-21     Legal Assistant                    IT  Affluent Customer
# 719   1931-10-23  Recruiting Manager                Retail  Affluent Customer
# 1091  1935-08-22  VP Quality Control                Retail      Mass Customer
#
#      deceased_indicator owns_car  tenure
# 33                    N       No    20.0
# 719                   N       No     6.0
# 1091                  N       No     5.0

# %%
cus_demo.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure
# count                          4000.000000  4000.000000
# mean                             48.890000    10.425250
# std                              28.715005     5.810108
# min                               0.000000     0.000000
# 25%                              24.000000     6.000000
# 50%                              48.000000    10.000000
# 75%                              73.000000    15.000000
# max                              99.000000    22.000000

# %%
cus_demo.loc[cus_demo['gender'] == "Female"]
# Out:
#      first_name last_name  gender  past_3_years_bike_related_purchases  \
# 1091     Katlin   Creddon  Female                                   56
# 3409    Merrili   Brittin  Female                                   93
# 1176   Bobbette     Pozzi  Female                                   47
# 3470      Brita    Afonso  Female                                   95
# 2812    Lillian  Crookall  Female                                   51
# ...         ...       ...     ...                                  ...
# 2758    Melodee   Hendrik  Female                                   16
# 211      Nanice     Ellse  Female                                   21
# 2295   Nathalia    Sanger  Female                                   16
# 3434    Stevena   Allcock  Female                                   80
# 1887      Sibyl   Scholtz  Female                                   67
#
#              DOB                   job_title job_industry_category  \
# 1091  1935-08-22          VP Quality Control                Retail
# 3409  1940-09-22                           0              Property
# 1176  1953-08-31                Food Chemist                Health
# 3470  1953-09-05            Quality Engineer                    IT
# 2812  1953-09-10           Chemical Engineer         Manufacturing
# ...          ...                         ...                   ...
# 2758  2001-11-14                    Operator                Health
# 211   2001-11-19  Desktop Support Technician                    IT
# 2295  2002-01-01                Geologist IV                Retail
# 3434  2002-01-15               Senior Editor                     0
# 1887  2002-01-26                Food Chemist                Health
#
#          wealth_segment deceased_indicator owns_car  tenure
# 1091      Mass Customer                  N       No     5.0
# 3409      Mass Customer                  N       No    16.0
# 1176  Affluent Customer                  N      Yes     6.0
# 3470     High Net Worth                  N      Yes     8.0
# 2812      Mass Customer                  N      Yes    11.0
# ...                 ...                ...      ...     ...
# 2758  Affluent Customer                  N      Yes     1.0
# 211   Affluent Customer                  N       No     1.0
# 2295  Affluent Customer                  N       No     1.0
# 3434  Affluent Customer                  N       No     1.0
# 1887      Mass Customer                  N      Yes     1.0
#
# [2039 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['gender'] == "Male"]
# Out:
#      first_name    last_name gender  past_3_years_bike_related_purchases  \
# 719      Darrel        Canet   Male                                   67
# 2412      Abbey       Murrow   Male                                   27
# 657        Donn      Bonnell   Male                                   38
# 1242    Robbert       Blakey   Male                                   73
# 1564        Jay  Janiszewski   Male                                   71
# ...         ...          ...    ...                                  ...
# 469      Darbee    Klimowicz   Male                                   22
# 3948      Costa  Sleightholm   Male                                   24
# 421        Vito       Norker   Male                                   78
# 2857  Benedicto        Radki   Male                                    4
# 65       Anselm        Gawne   Male                                   46
#
#              DOB                 job_title job_industry_category  \
# 719   1931-10-23        Recruiting Manager                Retail
# 2412  1943-08-11  Environmental Specialist         Manufacturing
# 657   1944-01-24            Tax Accountant         Manufacturing
# 1242  1953-08-09     Research Assistant II                Retail
# 1564  1953-08-17      Sales Representative                Retail
# ...          ...                       ...                   ...
# 469   2001-12-19          Internal Auditor                Retail
# 3948  2001-12-19           Web Designer IV         Manufacturing
# 421   2002-01-06                         0         Manufacturing
# 2857  2002-01-09        Recruiting Manager                     0
# 65    2002-03-11         Account Executive           Argiculture
#
#          wealth_segment deceased_indicator owns_car  tenure
# 719   Affluent Customer                  N       No     6.0
# 2412     High Net Worth                  N      Yes    17.0
# 657   Affluent Customer                  N      Yes     8.0
# 1242      Mass Customer                  N       No     8.0
# 1564     High Net Worth                  N      Yes    11.0
# ...                 ...                ...      ...     ...
# 469       Mass Customer                  N       No     1.0
# 3948     High Net Worth                  N      Yes     1.0
# 421   Affluent Customer                  N       No     1.0
# 2857      Mass Customer                  N      Yes     1.0
# 65       High Net Worth                  N       No     1.0
#
# [1873 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['gender'] == "Undefined"]
# Out:
#      first_name   last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah    Bachmann  Undefined                                   59
# 143        Jory  Barrabeale  Undefined                                   71
# 167      Reggie   Broggetti  Undefined                                    8
# 266       Edgar     Buckler  Undefined                                   53
# 289     Giorgio      Kevane  Undefined                                   42
# ...         ...         ...        ...                                  ...
# 3778      Ulick      Daspar  Undefined                                   68
# 3882      Nissa      Conrad  Undefined                                   35
# 3930      Kylie       Epine  Undefined                                   19
# 3934     Teodor   Alfonsini  Undefined                                   72
# 3997     Sarene     Woolley  Undefined                                   60
#
#              DOB               job_title job_industry_category  \
# 33    1843-12-21         Legal Assistant                    IT
# 143            0      Environmental Tech                    IT
# 167            0         General Manager                    IT
# 266            0                       0                    IT
# 289            0  Senior Sales Associate                    IT
# ...          ...                     ...                   ...
# 3778           0                       0                    IT
# 3882           0         Legal Assistant                    IT
# 3930           0                       0                    IT
# 3934           0                       0                    IT
# 3997           0       Assistant Manager                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 143       Mass Customer                  N       No     0.0
# 167   Affluent Customer                  N      Yes     0.0
# 266      High Net Worth                  N       No     0.0
# 289       Mass Customer                  N       No     0.0
# ...                 ...                ...      ...     ...
# 3778  Affluent Customer                  N       No     0.0
# 3882      Mass Customer                  N       No     0.0
# 3930     High Net Worth                  N      Yes     0.0
# 3934     High Net Worth                  N      Yes     0.0
# 3997     High Net Worth                  N       No     0.0
#
# [88 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['wealth_segment'] == "High Net Worth"]
# Out:
#      first_name        last_name     gender  \
# 2412      Abbey           Murrow       Male
# 1564        Jay      Janiszewski       Male
# 3470      Brita           Afonso     Female
# 2018       Neda           Perkis     Female
# 2745   Carmelia  Egle of Germany     Female
# ...         ...              ...        ...
# 3311     Franky        Nanninini  Undefined
# 3564     Charyl        Pottiphar  Undefined
# 3930      Kylie            Epine  Undefined
# 3934     Teodor        Alfonsini  Undefined
# 3997     Sarene          Woolley  Undefined
#
#       past_3_years_bike_related_purchases         DOB  \
# 2412                                   27  1943-08-11
# 1564                                   71  1953-08-17
# 3470                                   95  1953-09-05
# 2018                                   48  1953-09-13
# 2745                                   97  1953-10-25
# ...                                   ...         ...
# 3311                                   49           0
# 3564                                   14           0
# 3930                                   19           0
# 3934                                   72           0
# 3997                                   60           0
#
#                      job_title job_industry_category  wealth_segment  \
# 2412  Environmental Specialist         Manufacturing  High Net Worth
# 1564      Sales Representative                Retail  High Net Worth
# 3470          Quality Engineer                    IT  High Net Worth
# 2018              VP Marketing         Entertainment  High Net Worth
# 2745                   Actuary    Financial Services  High Net Worth
# ...                        ...                   ...             ...
# 3311    Administrative Officer                    IT  High Net Worth
# 3564       Structural Engineer                    IT  High Net Worth
# 3930                         0                    IT  High Net Worth
# 3934                         0                    IT  High Net Worth
# 3997         Assistant Manager                    IT  High Net Worth
#
#      deceased_indicator owns_car  tenure
# 2412                  N      Yes    17.0
# 1564                  N      Yes    11.0
# 3470                  N      Yes     8.0
# 2018                  N       No    17.0
# 2745                  N      Yes     7.0
# ...                 ...      ...     ...
# 3311                  N       No     0.0
# 3564                  N      Yes     0.0
# 3930                  N      Yes     0.0
# 3934                  N      Yes     0.0
# 3997                  N       No     0.0
#
# [1021 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['wealth_segment'] == "Affluent Customer"]
# Out:
#      first_name   last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah    Bachmann  Undefined                                   59
# 719      Darrel       Canet       Male                                   67
# 657        Donn     Bonnell       Male                                   38
# 1176   Bobbette       Pozzi     Female                                   47
# 1904  Corabelle           0     Female                                   21
# ...         ...         ...        ...                                  ...
# 3297  Christine    Baignard  Undefined                                    1
# 3321        Hew     Sworder  Undefined                                   24
# 3509     Jemima       Izaac  Undefined                                   48
# 3512  Enriqueta  Waterhowse  Undefined                                   80
# 3778      Ulick      Daspar  Undefined                                   68
#
#              DOB             job_title job_industry_category  \
# 33    1843-12-21       Legal Assistant                    IT
# 719   1931-10-23    Recruiting Manager                Retail
# 657   1944-01-24        Tax Accountant         Manufacturing
# 1176  1953-08-31          Food Chemist                Health
# 1904  1953-09-17  Help Desk Technician         Manufacturing
# ...          ...                   ...                   ...
# 3297           0    VP Quality Control                    IT
# 3321           0     Financial Analyst    Financial Services
# 3509           0  Safety Technician II                    IT
# 3512           0      Internal Auditor                    IT
# 3778           0                     0                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 719   Affluent Customer                  N       No     6.0
# 657   Affluent Customer                  N      Yes     8.0
# 1176  Affluent Customer                  N      Yes     6.0
# 1904  Affluent Customer                  N       No    15.0
# ...                 ...                ...      ...     ...
# 3297  Affluent Customer                  N      Yes     0.0
# 3321  Affluent Customer                  N      Yes     0.0
# 3509  Affluent Customer                  N      Yes     0.0
# 3512  Affluent Customer                  N      Yes     0.0
# 3778  Affluent Customer                  N       No     0.0
#
# [979 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['wealth_segment'] == "Mass Customer"]
# Out:
#      first_name   last_name     gender  past_3_years_bike_related_purchases  \
# 1091     Katlin     Creddon     Female                                   56
# 3409    Merrili     Brittin     Female                                   93
# 1242    Robbert      Blakey       Male                                   73
# 2812    Lillian    Crookall     Female                                   51
# 1914      Dusty     Tesimon     Female                                   40
# ...         ...         ...        ...                                  ...
# 3472  Sanderson     Alloway  Undefined                                   34
# 3653     Kenyon  Paddefield  Undefined                                   78
# 3717    Damiano           0  Undefined                                   22
# 3726        Eba       Youle  Undefined                                   65
# 3882      Nissa      Conrad  Undefined                                   35
#
#              DOB                      job_title job_industry_category  \
# 1091  1935-08-22             VP Quality Control                Retail
# 3409  1940-09-22                              0              Property
# 1242  1953-08-09          Research Assistant II                Retail
# 2812  1953-09-10              Chemical Engineer         Manufacturing
# 1914  1953-10-12                  Social Worker                Health
# ...          ...                            ...                   ...
# 3472           0  Analog Circuit Design manager                    IT
# 3653           0            Electrical Engineer         Manufacturing
# 3717           0                   Geologist IV                    IT
# 3726           0            Assistant Professor                    IT
# 3882           0                Legal Assistant                    IT
#
#      wealth_segment deceased_indicator owns_car  tenure
# 1091  Mass Customer                  N       No     5.0
# 3409  Mass Customer                  N       No    16.0
# 1242  Mass Customer                  N       No     8.0
# 2812  Mass Customer                  N      Yes    11.0
# 1914  Mass Customer                  N      Yes    12.0
# ...             ...                ...      ...     ...
# 3472  Mass Customer                  N       No     0.0
# 3653  Mass Customer                  N       No     0.0
# 3717  Mass Customer                  N      Yes     0.0
# 3726  Mass Customer                  N       No     0.0
# 3882  Mass Customer                  N       No     0.0
#
# [2000 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['deceased_indicator'] == "N"]
# Out:
#      first_name  last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah   Bachmann  Undefined                                   59
# 719      Darrel      Canet       Male                                   67
# 1091     Katlin    Creddon     Female                                   56
# 3409    Merrili    Brittin     Female                                   93
# 2412      Abbey     Murrow       Male                                   27
# ...         ...        ...        ...                                  ...
# 3778      Ulick     Daspar  Undefined                                   68
# 3882      Nissa     Conrad  Undefined                                   35
# 3930      Kylie      Epine  Undefined                                   19
# 3934     Teodor  Alfonsini  Undefined                                   72
# 3997     Sarene    Woolley  Undefined                                   60
#
#              DOB                 job_title job_industry_category  \
# 33    1843-12-21           Legal Assistant                    IT
# 719   1931-10-23        Recruiting Manager                Retail
# 1091  1935-08-22        VP Quality Control                Retail
# 3409  1940-09-22                         0              Property
# 2412  1943-08-11  Environmental Specialist         Manufacturing
# ...          ...                       ...                   ...
# 3778           0                         0                    IT
# 3882           0           Legal Assistant                    IT
# 3930           0                         0                    IT
# 3934           0                         0                    IT
# 3997           0         Assistant Manager                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 719   Affluent Customer                  N       No     6.0
# 1091      Mass Customer                  N       No     5.0
# 3409      Mass Customer                  N       No    16.0
# 2412     High Net Worth                  N      Yes    17.0
# ...                 ...                ...      ...     ...
# 3778  Affluent Customer                  N       No     0.0
# 3882      Mass Customer                  N       No     0.0
# 3930     High Net Worth                  N      Yes     0.0
# 3934     High Net Worth                  N      Yes     0.0
# 3997     High Net Worth                  N       No     0.0
#
# [3998 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['deceased_indicator'] == "Y"]
# Out:
#      first_name    last_name  gender  past_3_years_bike_related_purchases  \
# 3789     Kurtis       Morson    Male                                   91
# 752        Josy  St. Quentin  Female                                   82
#
#              DOB      job_title job_industry_category     wealth_segment  \
# 3789  1959-05-31  Senior Editor                Retail      Mass Customer
# 752   1970-03-07   Food Chemist                Health  Affluent Customer
#
#      deceased_indicator owns_car  tenure
# 3789                  Y      Yes     9.0
# 752                   Y      Yes     6.0

# %%
cus_demo.loc[cus_demo['owns_car'] == "Yes"]
# Out:
#      first_name    last_name     gender  past_3_years_bike_related_purchases  \
# 2412      Abbey       Murrow       Male                                   27
# 657        Donn      Bonnell       Male                                   38
# 1564        Jay  Janiszewski       Male                                   71
# 1176   Bobbette        Pozzi     Female                                   47
# 3470      Brita       Afonso     Female                                   95
# ...         ...          ...        ...                                  ...
# 3512  Enriqueta   Waterhowse  Undefined                                   80
# 3564     Charyl    Pottiphar  Undefined                                   14
# 3717    Damiano            0  Undefined                                   22
# 3930      Kylie        Epine  Undefined                                   19
# 3934     Teodor    Alfonsini  Undefined                                   72
#
#              DOB                 job_title job_industry_category  \
# 2412  1943-08-11  Environmental Specialist         Manufacturing
# 657   1944-01-24            Tax Accountant         Manufacturing
# 1564  1953-08-17      Sales Representative                Retail
# 1176  1953-08-31              Food Chemist                Health
# 3470  1953-09-05          Quality Engineer                    IT
# ...          ...                       ...                   ...
# 3512           0          Internal Auditor                    IT
# 3564           0       Structural Engineer                    IT
# 3717           0              Geologist IV                    IT
# 3930           0                         0                    IT
# 3934           0                         0                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 2412     High Net Worth                  N      Yes    17.0
# 657   Affluent Customer                  N      Yes     8.0
# 1564     High Net Worth                  N      Yes    11.0
# 1176  Affluent Customer                  N      Yes     6.0
# 3470     High Net Worth                  N      Yes     8.0
# ...                 ...                ...      ...     ...
# 3512  Affluent Customer                  N      Yes     0.0
# 3564     High Net Worth                  N      Yes     0.0
# 3717      Mass Customer                  N      Yes     0.0
# 3930     High Net Worth                  N      Yes     0.0
# 3934     High Net Worth                  N      Yes     0.0
#
# [2024 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['owns_car'] == "No"]
# Out:
#      first_name   last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah    Bachmann  Undefined                                   59
# 719      Darrel       Canet       Male                                   67
# 1091     Katlin     Creddon     Female                                   56
# 3409    Merrili     Brittin     Female                                   93
# 1242    Robbert      Blakey       Male                                   73
# ...         ...         ...        ...                                  ...
# 3653     Kenyon  Paddefield  Undefined                                   78
# 3726        Eba       Youle  Undefined                                   65
# 3778      Ulick      Daspar  Undefined                                   68
# 3882      Nissa      Conrad  Undefined                                   35
# 3997     Sarene     Woolley  Undefined                                   60
#
#              DOB              job_title job_industry_category  \
# 33    1843-12-21        Legal Assistant                    IT
# 719   1931-10-23     Recruiting Manager                Retail
# 1091  1935-08-22     VP Quality Control                Retail
# 3409  1940-09-22                      0              Property
# 1242  1953-08-09  Research Assistant II                Retail
# ...          ...                    ...                   ...
# 3653           0    Electrical Engineer         Manufacturing
# 3726           0    Assistant Professor                    IT
# 3778           0                      0                    IT
# 3882           0        Legal Assistant                    IT
# 3997           0      Assistant Manager                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 719   Affluent Customer                  N       No     6.0
# 1091      Mass Customer                  N       No     5.0
# 3409      Mass Customer                  N       No    16.0
# 1242      Mass Customer                  N       No     8.0
# ...                 ...                ...      ...     ...
# 3653      Mass Customer                  N       No     0.0
# 3726      Mass Customer                  N       No     0.0
# 3778  Affluent Customer                  N       No     0.0
# 3882      Mass Customer                  N       No     0.0
# 3997     High Net Worth                  N       No     0.0
#
# [1976 rows x 11 columns]

# %%
cus_demo.loc[cus_demo['job_industry_category'] == "IT"]
# Out:
#      first_name  last_name     gender  past_3_years_bike_related_purchases  \
# 33     Jephthah   Bachmann  Undefined                                   59
# 3470      Brita     Afonso     Female                                   95
# 2494    Gwenore      Suero     Female                                   89
# 254      Keeley     Kruger     Female                                    2
# 2609    Arliene  Bartolijn     Female                                   41
# ...         ...        ...        ...                                  ...
# 3778      Ulick     Daspar  Undefined                                   68
# 3882      Nissa     Conrad  Undefined                                   35
# 3930      Kylie      Epine  Undefined                                   19
# 3934     Teodor  Alfonsini  Undefined                                   72
# 3997     Sarene    Woolley  Undefined                                   60
#
#              DOB                   job_title job_industry_category  \
# 33    1843-12-21             Legal Assistant                    IT
# 3470  1953-09-05            Quality Engineer                    IT
# 2494  1953-11-12         Assistant Professor                    IT
# 254   1954-01-15  Desktop Support Technician                    IT
# 2609  1954-04-30         Account Coordinator                    IT
# ...          ...                         ...                   ...
# 3778           0                           0                    IT
# 3882           0             Legal Assistant                    IT
# 3930           0                           0                    IT
# 3934           0                           0                    IT
# 3997           0           Assistant Manager                    IT
#
#          wealth_segment deceased_indicator owns_car  tenure
# 33    Affluent Customer                  N       No    20.0
# 3470     High Net Worth                  N      Yes     8.0
# 2494  Affluent Customer                  N       No    17.0
# 254       Mass Customer                  N       No     5.0
# 2609      Mass Customer                  N       No    10.0
# ...                 ...                ...      ...     ...
# 3778  Affluent Customer                  N       No     0.0
# 3882      Mass Customer                  N       No     0.0
# 3930     High Net Worth                  N      Yes     0.0
# 3934     High Net Worth                  N      Yes     0.0
# 3997     High Net Worth                  N       No     0.0
#
# [223 rows x 11 columns]

# %%
print(cus_demo['wealth_segment'].where(cus_demo['tenure'] < 11))
# Out:
# 33                    NaN
# 719     Affluent Customer
# 1091        Mass Customer
# 3409                  NaN
# 2412                  NaN
#               ...
# 3778    Affluent Customer
# 3882        Mass Customer
# 3930       High Net Worth
# 3934       High Net Worth
# 3997       High Net Worth
# Name: wealth_segment, Length: 4000, dtype: object

# %%
print(cus_demo['job_industry_category'].where(cus_demo['wealth_segment'] == "High Net Worth"))
# Out:
# 33                NaN
# 719               NaN
# 1091              NaN
# 3409              NaN
# 2412    Manufacturing
#             ...
# 3778              NaN
# 3882              NaN
# 3930               IT
# 3934               IT
# 3997               IT
# Name: job_industry_category, Length: 4000, dtype: object
